# %% [markdown]
# # Cybersecurity advanced
# ## Lab 03

# %% [markdown]
# Links to Syllabus
#
# - [Theoretical](https://hogenttin.github.io/cybersecurity-advanced/lesson-3/theory/)
# - [Practical](https://hogenttin.github.io/cybersecurity-advanced/lesson-3/lab/)

# %% [markdown]
# ### SSH Client
#
# Create / added a ssh config file:
#
# ```powershell
# #DEVOPS
# #---
# Host app-dv
#     HostName vichogent.be
#     User vicuser
#     Port 40046
#     IdentityFile C:\Users\maart\.ssh\VIC
#
# Host build-dv
#     HostName vichogent.be
#     User vicuser
#     Port 40047
#     IdentityFile C:\Users\maart\.ssh\VIC
#
# Host db-dv
#     HostName vichogent.be
#     User vicuser
#     Port 40050
#     IdentityFile C:\Users\maart\.ssh\VIC
#
# Host monitoring-dv
#     HostName vichogent.be
#     User vicuser
#     Port 40056
#     IdentityFile C:\Users\maart\.ssh\VIC
#
# #CYBERADVANCED
# #---
#
# Host companyrouter
#     HostName 192.168.62.253
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#
# Host isprouter
#     HostName 192.168.62.254
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#     ProxyJump companyrouter
#
# Host database
#     HostName 172.30.0.15
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#     ProxyJump companyrouter
#
# Host web
#     HostName 172.30.20.10
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#     ProxyJump companyrouter
#
# Host remote-employee
#     HostName 172.10.10.123
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#     ProxyJump companyrouter
#
# Host homerouter
#     HostName 172.10.10.254
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#     ProxyJump companyrouter
#
# Host employee
#     HostName 172.30.0.123
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#     ProxyJump companyrouter
#
# Host dns
#     HostName 172.30.0.4
#     User vagrant
#     IdentityFile C:\Users\maart\.ssh\cyber
#     ProxyJump companyrouter
# ```
#
# After, the key was added to every vm's authorized_keys file
